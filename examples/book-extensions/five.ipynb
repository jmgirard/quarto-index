# %% [markdown]
# # An .ipynb chapter
#
# A notebook is a chapter Quarto renders and this route does not read. Its
# mark names the book's second index: parsed as markdown, the raw JSON's own
# quoting rides into that name, no declared index matches it, and the term is
# filed into the first declared index instead.
#
# [Gantry]{.index index="aside"}
